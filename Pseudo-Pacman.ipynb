# %% [markdown]
# 4. Un pseudo-Pacman:
# Gojo y Dante est´an jugando un nuevo tipo de Pacman. Cada uno mueve
# su Pacman en un grid de 20x20, por turnos y con acciones: arriba (U),
# abajo (D), izquierda (L), derecha (R), parar (S). Al comienzo de colocan
# 100 puntos de comida en el grid de manera aleatoria. Despu´es de que un
# punto de comida es consumido por cualquiera de los Pacmans, otra comida
# es puesta inmediatamente de manera aleatoria en un lugar vac´ıo del grid.
# Los dos Pacmans empiezan con un punto de fuerza y ganan un nivel por
# cada comida que consumen. Gana el primero que llegue al nivel 100 de
# fuerza o el que se coma al otro Pacman, esto ocurre cu´ado los dos Pacmans
# ocupan el mismo grid y el que tiene mayor fuerza se come al de menor, si
# tienen la misma fuerza no pasa nada. Cu´al de los siguientes enunciados es
# una representaci´on de estado v´alida (justifica tu respuesta):
# a) Una lista de locaciones de comida visitadas y las coordenadas (x, y)
# de cada Pacman y su nivel de fuerza.
# b) Las coordenadas (x, y) de cada Pacman y su nivel de fuerza.
# c) Una lista de las locaciones de comida actuales y las coordenadas (x, y)
# de cada Pacman y su nivel de fuerza.
# d) 100 booleanos para la comida y las coordenadas (x, y) de cada Pacman y su nivel de fuerza.
# e) Ninguna de las anteriores

# %% [markdown]
# Ya que en una representación de estado buscamos describir o determinar la condición del juego y como cambia a función del tiempo , es decir determinar la evolucion despues de cada accion.
#
# Entonces en primer lugar , analicemos porque cambia el juego. Por descripcion del juego, éste cambia si: se mueven los pacmen , si caen en un grid con comida (el cual sube nivel de fuerza y reaparece otra), si ocupan el mismo grid , si uno gana. Entonces para saber que cambia en el juego al ejecutar una acción , en primer lugar se necesita saber donde esta la comida , ya que eso se proyecta en si se gana fuerza al moverse  y si se dispara una nueva colocación de la comida.
#
# Como a) no incluye la localizacion de la comida actual , la descartamos. La opción b) no proporciona información de comida. Y la d) al solo dar 100 booleanos no alcanza a analizar el tablero completo de 400 grid. Así la opción mas adecuada debe ser la c).

# %% [markdown]
# 5. Si Gojo decide representar el estado con 400 booleanos para las locaciones
# de comida (uno por cada locaci´on del grid) y las coordenadas (x, y) de
# cada Pacman y su nivel de fuerza. Cu´al es el tama˜no del espacio de estado
# bajo esta representaci´on.

# %% [markdown]
# Observacion 0) El grid general tiene 400 casillas . Y la fuerza de los pacmen ya que son 100 cada uno tiene 100² posibilidades.
#
# Observacion1) Para analizar las diferentes ubicaciones de los pacmen hay dos casos.
#
# Caso1 : Estan en ubicaciones distintas, asi existen 400x399 formas de estado
# Caso 2: Estan en la misma casilla, entonces existen 400 formas.
#
# Observacion 2) La comida se acomoda de forma aleatoria, pero tambien se splitea en dos casos
# Caso 1: Si estan en ubicaciónes distintas, quedan solos 398 casillas disponibles para poner comida, entonces las posibilidades son las combinaciones de 398 en 100
# Caso 2: Si estan en las mismas solo quedan 399 entonces analogamente hay 399 en 100.
#
# Sea n= Combinaciones de 398 en 100 y m = Combinaciones de 399 en 100.
# Por observaciones 0,1,2 el espacio de estados es = 100²(400*399*(n)+400*(m))
